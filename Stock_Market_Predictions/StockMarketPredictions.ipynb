# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\leoma\anaconda3\lib\site-packages (0.2.63)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (0.11.3)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\leoma\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leoma\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\leoma\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\leoma\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leoma\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leoma\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\leoma\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leoma\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leoma\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\leoma\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\leoma\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
import yfinance as yf # Import the yahoo finance packages into the environment

# %%
sp500 = yf.Ticker("^GSPC") # Brings through the data for the S&P 500

# %%
sp500 = sp500.history(period="max") # Gets all the data of the S&P 500

# %%
sp500 # Plots the S&P 500 data on a table
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-12 00:00:00-04:00  6009.899902  6045.430176  6003.879883  6045.259766
# 2025-06-13 00:00:00-04:00  6000.560059  6026.160156  5963.209961  5976.970215
# 2025-06-16 00:00:00-04:00  6004.000000  6050.830078  6004.000000  6033.109863
# 2025-06-17 00:00:00-04:00  6012.149902  6023.250000  5974.799805  5982.720215
# 2025-06-18 00:00:00-04:00  5987.930176  6018.250000  5971.890137  5980.870117
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2025-06-12 00:00:00-04:00  4669500000        0.0           0.0
# 2025-06-13 00:00:00-04:00  5258910000        0.0           0.0
# 2025-06-16 00:00:00-04:00  5111710000        0.0           0.0
# 2025-06-17 00:00:00-04:00  4955700000        0.0           0.0
# 2025-06-18 00:00:00-04:00  5106470000        0.0           0.0
#
# [24482 rows x 7 columns]

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-06-05 00:00:00-04:00', '2025-06-06 00:00:00-04:00',
#                '2025-06-09 00:00:00-04:00', '2025-06-10 00:00:00-04:00',
#                '2025-06-11 00:00:00-04:00', '2025-06-12 00:00:00-04:00',
#                '2025-06-13 00:00:00-04:00', '2025-06-16 00:00:00-04:00',
#                '2025-06-17 00:00:00-04:00', '2025-06-18 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24482, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True) # This plots the data with the Y axis the close price and thr X axis the dates
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Stock Splits"]
del sp500["Dividends"] # deltes the columns from the dataframe

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1) # Creates a tommorrow column which is equal to the close price of the day in front

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-12 00:00:00-04:00  6009.899902  6045.430176  6003.879883  6045.259766
# 2025-06-13 00:00:00-04:00  6000.560059  6026.160156  5963.209961  5976.970215
# 2025-06-16 00:00:00-04:00  6004.000000  6050.830078  6004.000000  6033.109863
# 2025-06-17 00:00:00-04:00  6012.149902  6023.250000  5974.799805  5982.720215
# 2025-06-18 00:00:00-04:00  5987.930176  6018.250000  5971.890137  5980.870117
#
#                                Volume     Tomorrow
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000
# 1928-01-03 00:00:00-05:00           0    17.719999
# 1928-01-04 00:00:00-05:00           0    17.549999
# 1928-01-05 00:00:00-05:00           0    17.660000
# 1928-01-06 00:00:00-05:00           0    17.500000
# ...                               ...          ...
# 2025-06-12 00:00:00-04:00  4669500000  5976.970215
# 2025-06-13 00:00:00-04:00  5258910000  6033.109863
# 2025-06-16 00:00:00-04:00  5111710000  5982.720215
# 2025-06-17 00:00:00-04:00  4955700000  5980.870117
# 2025-06-18 00:00:00-04:00  5106470000          NaN
#
# [24482 rows x 6 columns]

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
# Create a target column that will display a 0 if the tomorrow price is less than the close price or a 1 if the tomorrow price is greater than the close

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-12 00:00:00-04:00  6009.899902  6045.430176  6003.879883  6045.259766
# 2025-06-13 00:00:00-04:00  6000.560059  6026.160156  5963.209961  5976.970215
# 2025-06-16 00:00:00-04:00  6004.000000  6050.830078  6004.000000  6033.109863
# 2025-06-17 00:00:00-04:00  6012.149902  6023.250000  5974.799805  5982.720215
# 2025-06-18 00:00:00-04:00  5987.930176  6018.250000  5971.890137  5980.870117
#
#                                Volume     Tomorrow  Target
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000       1
# 1928-01-03 00:00:00-05:00           0    17.719999       0
# 1928-01-04 00:00:00-05:00           0    17.549999       0
# 1928-01-05 00:00:00-05:00           0    17.660000       1
# 1928-01-06 00:00:00-05:00           0    17.500000       0
# ...                               ...          ...     ...
# 2025-06-12 00:00:00-04:00  4669500000  5976.970215       0
# 2025-06-13 00:00:00-04:00  5258910000  6033.109863       1
# 2025-06-16 00:00:00-04:00  5111710000  5982.720215       0
# 2025-06-17 00:00:00-04:00  4955700000  5980.870117       0
# 2025-06-18 00:00:00-04:00  5106470000          NaN       0
#
# [24482 rows x 7 columns]

# %%
sp500 = sp500.loc["1990-01-01":].copy() # This only takes lows where the index is at least 1990 january the 1st

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-06-12 00:00:00-04:00  6009.899902  6045.430176  6003.879883  6045.259766
# 2025-06-13 00:00:00-04:00  6000.560059  6026.160156  5963.209961  5976.970215
# 2025-06-16 00:00:00-04:00  6004.000000  6050.830078  6004.000000  6033.109863
# 2025-06-17 00:00:00-04:00  6012.149902  6023.250000  5974.799805  5982.720215
# 2025-06-18 00:00:00-04:00  5987.930176  6018.250000  5971.890137  5980.870117
#
#                                Volume     Tomorrow  Target
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0
# ...                               ...          ...     ...
# 2025-06-12 00:00:00-04:00  4669500000  5976.970215       0
# 2025-06-13 00:00:00-04:00  5258910000  6033.109863       1
# 2025-06-16 00:00:00-04:00  5111710000  5982.720215       0
# 2025-06-17 00:00:00-04:00  4955700000  5980.870117       0
# 2025-06-18 00:00:00-04:00  5106470000          NaN       0
#
# [8932 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
# Using random forest as it trains mutiple decsion trees anc averaging the results. This stops overfitting and non-linear relationships.
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
# Creates 100 different decision trees, Helps protect against overfitting, Random state means same results when the model is run mutiple times
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]
# Splits the data into train and test set. The test set is the forst 100 rows.
predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Trains model using the columns as predictors and guesses the Traget column value.
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score 
# This checks if the market actully went up when predicted it would
preds = model.predict(test[predictors])
#This tests the model using our test set

# %%
import pandas as pd 
# imports Pandas
preds = pd.Series(preds, index=test.index) 
# Turn the predictors into a pandas series

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5747126436781609

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"]) # Fitting the model using the training predictors
    preds = model.predict(test[predictors]) # Generating the predictors
    preds = pd.Series(preds, index=test.index, name="Predictions") #Tunr it into a series
    combined = pd.concat([test["Target"], preds], axis=1) # Combining everything together
    return combined # Returning the Combined dataframe

# %%
def backtest(data, model, predictors, start=2500, step=250): # Start takes 10 years of data and trains the model. While step trains the next year.
    all_predictions = [] # Creates a list of all dataframes. A dataframe is a single year

    for i in range(start, data.shape[0], step): #Cretaes a funtion to loop acroos the data year by year and make predictions for all years apart from the first 10.
        train = data.iloc[0:i].copy() 
        test = data.iloc[i:(i+step)].copy() # Splits the train and test data
        predictions = predict(train, test, predictors, model)  # Generates the predicitons
        all_predictions.append(predictions) # append the predicitons for that year
    return pd.concat(all_predictions) # combines all dataframe into one

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts() # Counts how many times the model preicted the market would go up or down
# Out:
# Predictions
# 0    3768
# 1    2664
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"]) # How accurate is this model
# Out:
# 0.53003003003003

# %%
predictions["Target"].value_counts() / predictions.shape[0] # This count the number of preictions and divides by number of rows total
# Out:
# Target
# 1    0.536381
# 0    0.463619
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]
# Out:
# C:\Users\leoma\AppData\Local\Temp\ipykernel_6784\1198986366.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
# C:\Users\leoma\AppData\Local\Temp\ipykernel_6784\1198986366.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

# %%
sp500 = sp500.dropna() # gets rid of any columns with NA

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2005-11-09 00:00:00-05:00  1218.589966  1226.589966  1216.530029  1220.650024
# 2005-11-10 00:00:00-05:00  1220.650024  1232.410034  1215.050049  1230.959961
# 2005-11-11 00:00:00-05:00  1230.959961  1235.699951  1230.719971  1234.719971
# 2005-11-14 00:00:00-05:00  1234.719971  1237.199951  1231.780029  1233.760010
# 2005-11-15 00:00:00-05:00  1233.760010  1237.939941  1226.410034  1229.010010
# ...                                ...          ...          ...          ...
# 2025-06-11 00:00:00-04:00  6049.379883  6059.399902  6002.319824  6022.240234
# 2025-06-12 00:00:00-04:00  6009.899902  6045.430176  6003.879883  6045.259766
# 2025-06-13 00:00:00-04:00  6000.560059  6026.160156  5963.209961  5976.970215
# 2025-06-16 00:00:00-04:00  6004.000000  6050.830078  6004.000000  6033.109863
# 2025-06-17 00:00:00-04:00  6012.149902  6023.250000  5974.799805  5982.720215
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2005-11-09 00:00:00-05:00  2214460000  1230.959961       1       1.000845
# 2005-11-10 00:00:00-05:00  2378460000  1234.719971       1       1.004205
# 2005-11-11 00:00:00-05:00  1773140000  1233.760010       0       1.001525
# 2005-11-14 00:00:00-05:00  1899780000  1229.010010       0       0.999611
# 2005-11-15 00:00:00-05:00  2359370000  1231.209961       1       0.998071
# ...                               ...          ...     ...            ...
# 2025-06-11 00:00:00-04:00  5111550000  6045.259766       1       0.998626
# 2025-06-12 00:00:00-04:00  4669500000  5976.970215       0       1.001908
# 2025-06-13 00:00:00-04:00  5258910000  6033.109863       1       0.994320
# 2025-06-16 00:00:00-04:00  5111710000  5982.720215       0       1.004674
# 2025-06-17 00:00:00-04:00  4955700000  5980.870117       0       0.995806
#
#                            Trend_2  Trend_5  Trend_60  Trend_250  Trend_1000  \
# Date
# 2005-11-09 00:00:00-05:00      1.0      4.0      32.0      138.0       523.0
# 2005-11-10 00:00:00-05:00      2.0      4.0      32.0      139.0       524.0
# 2005-11-11 00:00:00-05:00      2.0      4.0      33.0      140.0       524.0
# 2005-11-14 00:00:00-05:00      1.0      3.0      32.0      139.0       523.0
# 2005-11-15 00:00:00-05:00      0.0      3.0      31.0      138.0       523.0
# ...                            ...      ...       ...        ...         ...
# 2025-06-11 00:00:00-04:00      1.0      3.0      36.0      144.0       532.0
# 2025-06-12 00:00:00-04:00      1.0      4.0      37.0      144.0       533.0
# 2025-06-13 00:00:00-04:00      1.0      3.0      36.0      143.0       532.0
# 2025-06-16 00:00:00-04:00      1.0      3.0      37.0      144.0       532.0
# 2025-06-17 00:00:00-04:00      1.0      2.0      36.0      143.0       532.0
#
#                            Close_Ratio_5  Close_Ratio_60  Close_Ratio_250  \
# Date
# 2005-11-09 00:00:00-05:00       1.000184        1.007948         1.018560
# 2005-11-10 00:00:00-05:00       1.006813        1.016312         1.027001
# 2005-11-11 00:00:00-05:00       1.007486        1.019196         1.029935
# 2005-11-14 00:00:00-05:00       1.004907        1.018207         1.028956
# 2005-11-15 00:00:00-05:00       0.999341        1.014185         1.024839
# ...                                  ...             ...              ...
# 2025-06-11 00:00:00-04:00       1.003486        1.064516         1.049378
# 2025-06-12 00:00:00-04:00       1.003777        1.067231         1.052931
# 2025-06-13 00:00:00-04:00       0.993210        1.054240         1.040643
# 2025-06-16 00:00:00-04:00       1.001632        1.062985         1.049977
# 2025-06-17 00:00:00-04:00       0.995120        1.053132         1.040838
#
#                            Close_Ratio_1000
# Date
# 2005-11-09 00:00:00-05:00          1.141022
# 2005-11-10 00:00:00-05:00          1.150558
# 2005-11-11 00:00:00-05:00          1.153981
# 2005-11-14 00:00:00-05:00          1.153002
# 2005-11-15 00:00:00-05:00          1.148478
# ...                                     ...
# 2025-06-11 00:00:00-04:00          1.275963
# 2025-06-12 00:00:00-04:00          1.280331
# 2025-06-13 00:00:00-04:00          1.265398
# 2025-06-16 00:00:00-04:00          1.276801
# 2025-06-17 00:00:00-04:00          1.265670
#
# [4931 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"]) # Fitting the model using the training predictors
    preds = model.predict_proba(test[predictors])[:,1] # Generating the predictors in probability
    preds[preds >= .6] = 1
    preds [preds < .6] = 0 # Makes so value in the prediction column to only display 1 or 0 if the probability is more than 0.6
    preds = pd.Series(preds, index=test.index, name="Predictions") #Tunr it into a series
    combined = pd.concat([test["Target"], preds], axis=1) # Combining everything together
    return combined # Returning the Combined dataframe

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    1925
# 1.0     506
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5652173913043478
